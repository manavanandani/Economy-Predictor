# %% [markdown]
# ### GDP 2028 Prediction, for Each State and All India

# %%
import pandas as pd
import pickle

# %%
data = pd.read_csv('NITI_2028_DATA.csv', index_col=0)
data
# Out:
#                    Revenue_Deficits  Fiscal_Deficits  Revenue_Receipts
# Andhra Pradesh       13191.69405780   30923.00176510   170083.84293380  \
# Arunachal Pradesh    -1036.68158108    1921.40918235    31677.55468155
# Assam                 -991.11795878    9104.77293460   309704.02604335
# Bihar               -10925.80885748   29950.62102053   318551.44288458
# Chhattisgarh        -10481.66422782   10019.81522766   187076.08281920
# Goa                   -159.75853587    9019.49157623    28802.16083618
# Gujarat              -6614.88765259   31971.55329153   256242.25456114
# Haryana              16230.07002590   28645.15590048   162541.95365337
# Himachal Pradesh       993.52838567    4985.44372647    55121.89780796
# Jammu & Kashmir      -4277.50532814   14511.92427231   165648.63110974
# Jharkhand            -9640.89612201    8224.19058069   157653.46801969
# Karnataka            -1136.33971900   41649.86159035   288419.58568141
# Kerala               10811.43396746   32053.27553515   247972.31629802
# Madhya Pradesh        4003.19788686   38805.87132633   317650.95936006
# Maharashtra           5100.01335466   46609.59219481   493540.44061080
# Manipur              -1191.89162899     755.96393839    17709.18693333
# Meghalaya            -1164.42704073    1141.67064546    20903.52868290
# Mizoram               -163.67922884    1595.06786209    19113.76554128
# Nagaland              -546.71192515    2484.01879114    26108.12661695
# Odisha               -6963.58140093   38242.98011560   179892.56715760
# Punjab                9193.36671464   21119.61195883   112469.01076478
# Rajasthan              723.32090606   30205.94060192   315566.79781174
# Sikkim               -1914.93555402     559.11413698     8212.42558538
# Tamil Nadu            4358.87508540   81021.15637218   293939.31798798
# Telangana            -3980.00005346   94610.06851595   392314.90040997
# Tripura             -10576.03795218    9672.70630663    34900.38149652
# Uttar Pradesh       -82373.91726846   48777.88033435   776394.69855705
# Uttarakhand           -822.97277432    7845.88859608   107101.47868734
# West Bengal           2055.49896638   26384.15747339   365398.04349222
# All States          164032.09830672  568569.23981440  5865384.46012653
# Delhi               -11445.07814029    2577.15537947    93112.61287395
# Puducherry             143.72584272     606.79395253    10273.54535555
#
#                    Interest_Payments  Aggregate_Receipts  Own_Tax_Revenues
# Andhra Pradesh        17231.05978274     201838.61345190    59843.61483801  \
# Arunachal Pradesh       679.95489756      31671.79390137     1228.09806714
# Assam                  5629.63847636     309052.50211509    36147.76145485
# Bihar                 20415.66110383     379758.32478360   100328.70557772
# Chhattisgarh           8572.19376852     207332.79876861    53713.97002250
# Goa                    2492.22360423      34758.77461283     9049.69436510
# Gujarat               32138.01823611     342060.94747066   145777.53827526
# Haryana               36909.14843027     237825.83206025    80876.67661306
# Himachal Pradesh       6924.18841941      78701.67124062    13996.05353497
# Jammu & Kashmir       10605.36285655     216405.49797712    18478.10678686
# Jharkhand              6757.49449862     167772.15501999    46149.56609361
# Karnataka             32975.10265063     354946.34872599   174799.52845940
# Kerala                31521.77556202     309832.02131944   127972.44885768
# Madhya Pradesh        27509.19653211     471970.08738302   101477.25188461
# Maharashtra           56004.04215503     611567.06998825   270155.28512035
# Manipur                 692.55530596      21025.39382735     1961.39185716
# Meghalaya              1443.31129166      23670.94735290     2329.66673476
# Mizoram                1769.83153441      18468.96382008    18468.96382008
# Nagaland               2861.14106960      41763.11884954      931.17750551
# Odisha                 6673.14870077     250540.30494756    48239.33560895
# Punjab                22788.48609403     148060.27933983    61241.84737861
# Rajasthan             80462.73489959     503705.42129816   138171.64173978
# Sikkim                  771.67762134        771.67762134     1141.42578046
# Sikkim                         97.32322238         12579.51935911
# Tamil Nadu                   6219.62420168        464819.76626356
# Telangana                    3485.45018492          3485.45018492
# Tripura                       238.95283626         56936.07791704
# Uttar Pradesh               11622.50546609        808649.21848851
# Uttarakhand                  1133.10429609         92724.96423413
# West Bengal                  6740.54687099        332068.91509658
# All States                  89147.99459108       6749028.62113980
# Delhi                         554.67218817         84985.03242943
# Puducherry                    165.00812865         12554.81430818
#
#                    Social_Sector_Expenditure
# Andhra Pradesh                86375.91430129
# Arunachal Pradesh             12030.75187390
# Assam                         97275.79154701
# Bihar                        184552.28059806
# Chhattisgarh                 137387.94325776
# Goa                           16120.00008911
# Gujarat                      154407.39745344
# Haryana                       86257.09078625
# Himachal Pradesh              33598.29477036
# Jammu & Kashmir               36171.18599761
# Jharkhand                     42612.01619621
# Karnataka                    150635.14692638
# Kerala                       110099.54192230
# Madhya Pradesh               186189.48283849
# Maharashtra                  298338.46583712
# Manipur                        8750.11161393
# Meghalaya                     12315.13921804
# Mizoram                        7351.81258523
# Nagaland                      13305.11359625
# Odisha                       112067.16600879
# Punjab                        49313.03677841
# Rajasthan                    216625.90545130
# Sikkim                         5068.70167757
# Tamil Nadu                   176211.31754843
# Telangana                    292512.19628712
# Tripura                       29273.98566194
# Uttar Pradesh                354756.86264385
# Uttarakhand                   47484.75786981
# West Bengal                  164032.09830672
# All States                  3167373.34280660
# Delhi                         58347.17426371
# Puducherry                     5948.19170001

# %% [markdown]
# ### Load the Model

# %%
data.index.values
# Out:
# array(['Andhra Pradesh ', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'All States', 'Delhi', 'Puducherry'],
#       dtype=object)

# %%
filename = 'gdp_model.sav'
scalerfile = 'gdp_scale.sav'
loaded_model = pickle.load(open(filename, 'rb'))
loaded_scaler = pickle.load(open(scalerfile, 'rb'))

# %%
predicted_data = []
for state in data.iterrows():
    scaled = loaded_scaler.transform(state[1].values.reshape(1, -1))
    predicted = loaded_model.predict(scaled)
    predicted_data.append(predicted[0])
# Out:
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
predicted_frame = pd.DataFrame({'State':data.index.values, 'GDP_PREDICTED_2028':predicted_data})

# %%
pd.set_option('display.float_format', lambda x: '%.8f' %x)

# %% [markdown]
# ### Final Predicted GDP for 2028

# %%
predicted_frame
# Out:
#                 State  GDP_PREDICTED_2028
# 0     Andhra Pradesh     1745044.69473297
# 1   Arunachal Pradesh     439094.56937394
# 2               Assam    3747302.30367207
# 3               Bihar    5744102.48169865
# 4        Chhattisgarh    2247718.07443296
# 5                 Goa    1046316.67291526
# 6             Gujarat    4811869.80810657
# 7             Haryana    2022780.12986058
# 8    Himachal Pradesh     713169.60335390
# 9     Jammu & Kashmir    2095285.76118072
# 10          Jharkhand    2658997.42561376
# 11          Karnataka    4007274.19096094
# 12             Kerala    3072009.88600850
# 13     Madhya Pradesh    4643042.42760056
# 14        Maharashtra    5920965.51875467
# 15            Manipur     184033.02057923
# 16          Meghalaya     317905.04812484
# 17            Mizoram     270654.70879749
# 18           Nagaland     326316.13558578
# 19             Odisha    3376340.96338321
# 20             Punjab    1294512.65959848
# 21          Rajasthan    5327975.87223942
# 22             Sikkim     120654.57516558
# 23         Tamil Nadu    5128553.85909976
# 24          Telangana    6928377.73078844
# 25            Tripura    1379710.55524012
# 26      Uttar Pradesh   13322534.98690521
# 27        Uttarakhand    1093170.43136215
# 28        West Bengal    5876044.23335584
# 29         All States   86629292.00540620
# 30              Delhi    1285515.58194480
# 31         Puducherry     132426.63987624
