# %% [markdown]
# ### GDP 2026 Prediction, for Each State and All India

# %%
import pandas as pd
import pickle

# %%
data = pd.read_csv('NITI_2026_DATA.csv', index_col=0)
data
# Out:
#                    Revenue_Deficits  Fiscal_Deficits  Revenue_Receipts
# Andhra Pradesh         12414.067952     29093.704996      1.599392e+05  \
# Arunachal Pradesh       -987.352270      1829.836488      2.852725e+04
# Assam                   -941.206128      8713.809153      2.689798e+05
# Bihar                 -10132.275091     27877.890488      2.846989e+05
# Chhattisgarh           -9518.662483      9530.612883      1.663124e+05
# Goa                     -152.095957      8016.064288      2.577503e+04
# Gujarat                -6721.072793     30424.636637      2.329289e+05
# Haryana                15198.842878     26756.297560      1.459434e+05
# Himachal Pradesh         949.865102      4759.088834      5.031399e+04
# Jammu & Kashmir        -4099.076212     13306.294078      1.464506e+05
# Jharkhand              -8827.195201      7715.298032      1.406726e+05
# Karnataka              -1100.963660     38353.450423      2.621432e+05
# Kerala                 10354.801692     29840.667490      2.207459e+05
# Madhya Pradesh          2478.941973     35411.241105      2.857268e+05
# Maharashtra             5223.766101     43530.699872      4.461606e+05
# Manipur                -1142.245014       718.778414      1.632817e+04
# Meghalaya              -1118.907513      1058.978476      1.890758e+04
# Mizoram                 -154.312537      1470.498091      1.721690e+04
# Nagaland                -523.965772      2240.847770      2.346052e+04
# Odisha                 -6673.373018     33960.475732      1.629344e+05
# Punjab                  8762.981021     19660.969783      1.020095e+05
# Rajasthan                691.510685     28732.265382      2.835129e+05
# Sikkim                 -1753.715414       516.594025      7.674322e+03
# Tamil Nadu              4398.195296     73452.515381      2.696488e+05
# Telangana              -3450.000043     83146.515377      3.437543e+05
# Tripura                -9411.117620      8483.018340      3.118718e+04
# Uttar Pradesh         -74936.223832     46127.591654      6.941066e+05
# Uttarakhand             -766.330749      7270.415562      9.462027e+04
# West Bengal             1747.390326     25146.124287      3.260860e+05
# All States            148554.926454    532577.553806      5.264105e+06
# Delhi                 -10797.150782      2497.741508      8.444181e+04
# Puducherry               139.134766       602.746302      9.522621e+03
#
#                    Interest_Payments  Aggregate_Receipts  Own_Tax_Revenues
# Andhra Pradesh          16400.382765        1.905309e+05      5.744411e+04  \
# Arunachal Pradesh         648.023028        2.870544e+04      1.120550e+03
# Assam                    5217.913771        2.697593e+05      3.256904e+04
# Bihar                   18366.263411        3.393098e+05      8.964579e+04
# Chhattisgarh             7572.802422        1.847148e+05      4.855213e+04
# Goa                      2276.612133        3.113229e+04      8.324788e+03
# Gujarat                 29692.948049        3.098790e+05      1.338757e+05
# Haryana                 32505.245894        2.129158e+05      7.354976e+04
# Himachal Pradesh         6336.411226        7.088800e+04      1.281674e+04
# Karnataka                       1.364819e+05
# Kerala                          9.872306e+04
# Madhya Pradesh                  1.667873e+05
# Maharashtra                     2.694086e+05
# Manipur                         7.943731e+03
# Meghalaya                       1.110990e+04
# Mizoram                         6.693167e+03
# Nagaland                        1.184131e+04
# Odisha                          1.006766e+05
# Punjab                          4.462105e+04
# Rajasthan                       1.938190e+05
# Sikkim                          4.628087e+03
# Tamil Nadu                      1.602493e+05
# Telangana                       2.563807e+05
# Tripura                         2.587890e+04
# Uttar Pradesh                   3.181069e+05
# Uttarakhand                     4.257580e+04
# West Bengal                     1.485549e+05
# All States                      2.842783e+06
# Delhi                           5.276819e+04
# Puducherry                      5.451946e+03

# %% [markdown]
# ### Load the Model

# %%
data.index.values
# Out:
# array(['Andhra Pradesh ', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'All States', 'Delhi', 'Puducherry'],
#       dtype=object)

# %%
filename = 'gdp_model.sav'
scalerfile = 'gdp_scale.sav'
loaded_model = pickle.load(open(filename, 'rb'))
loaded_scaler = pickle.load(open(scalerfile, 'rb'))
# Out:
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
predicted_data = []
for state in data.iterrows():
    scaled = loaded_scaler.transform(state[1].values.reshape(1, -1))
    predicted = loaded_model.predict(scaled)
    predicted_data.append(predicted[0])
# Out:
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/manavanandani/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
predicted_frame = pd.DataFrame({'State':data.index.values, 'GDP_PREDICTED_2026':predicted_data})

# %%
pd.set_option('display.float_format', lambda x: '%.8f' %x)

# %% [markdown]
# ### Final Predicted GDP for 2026

# %%
predicted_frame
# Out:
#                 State  GDP_PREDICTED_2026
# 0     Andhra Pradesh     1679627.27646836
# 1   Arunachal Pradesh     398313.36388129
# 2               Assam    3280677.07376520
# 3               Bihar    5133943.80896188
# 4        Chhattisgarh    2013865.41633342
# 5                 Goa     916494.84706250
# 6             Gujarat    4417560.65857370
# 7             Haryana    1839897.28254923
# 8    Himachal Pradesh     653359.21492816
# 9     Jammu & Kashmir    1870723.93557125
# 10          Jharkhand    2368290.01332427
# 11          Karnataka    3686275.15319665
# 12             Kerala    2757642.10448240
# 13     Madhya Pradesh    4209788.23632671
# 14        Maharashtra    5459215.90035624
# 15            Manipur     172627.35783113
# 16          Meghalaya     286235.86565084
# 17            Mizoram     247001.14936076
# 18           Nagaland     292797.77623222
# 19             Odisha    3034145.36590209
# 20             Punjab    1192336.57276309
# 21          Rajasthan    4799099.26080163
# 22             Sikkim     110018.21831553
# 23         Tamil Nadu    4696300.91190591
# 24          Telangana    6134279.80626384
# 25            Tripura    1210566.08771236
# 26      Uttar Pradesh   11996341.96848837
# 27        Uttarakhand     989578.66724774
# 28        West Bengal    5241109.94694477
# 29         All States   78448897.71073370
# 30              Delhi    1202025.71439225
# 31         Puducherry     121220.22582776
